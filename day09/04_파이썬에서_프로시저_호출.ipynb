# %% [markdown]
# #### 라이브러리 정의

# %%
### 오라클 라이브러리
import cx_Oracle

# %%
### DB 서버 연결 및 접속 후 커서 생성
dsn = cx_Oracle.makedsn("localhost", 1521, "xe")
conn = cx_Oracle.connect("busan", "dbdb", dsn)
cursor = conn.cursor()

# %%
### 프로시저가 반환하는 타입으로 받아올 변수 정의
# var(cx_Oracle.CURSOR) : 오라클 CURSOR 타입의 행/열을 담을 객체로 정의
ref_cursor = cursor.var(cx_Oracle.CURSOR)
ref_cursor
# Out:
# <cx_Oracle.Var of type DB_TYPE_CURSOR with value None>

# %%
### 저장 프로시저 호출
# - callproc("호출할 프로시저 이름", [전달할 매개변수값, 받아올 변수명]) :
cursor.callproc("sp_getMemberView", ["a001", ref_cursor])
# Out:
# ['a001',
#  <cx_Oracle.Cursor on <cx_Oracle.Connection to busan@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=xe)))>>]

# %%
### 받아온 ref_cursor 내에 객체 추출
# - 객체 : 프로시저가 넘겨준 Sys_RefCursor 메모리
result_cursor = ref_cursor.getvalue()
result_cursor
# Out:
# <cx_Oracle.Cursor on <cx_Oracle.Connection to busan@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=xe)))>>

# %%
rows = result_cursor.fetchall()
rows
# Out:
# [('a001', '김은대', '대전시 동구 용운동', '대전')]

# %%
columns = result_cursor.description
columns
# Out:
# [('MEM_ID', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 15, 15, None, None, 0),
#  ('MEM_NAME', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 20, 20, None, None, 0),
#  ('MEM_ADD1', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 100, 100, None, None, 0),
#  ('AREA', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 4000, 4000, None, None, 1)]

# %%
import pandas as pd
df = pd.DataFrame(rows, columns=[col[0] for col in columns])
df
# Out:
#   MEM_ID MEM_NAME    MEM_ADD1 AREA
# 0   a001      김은대  대전시 동구 용운동   대전

# %% [markdown]
# - cx_Oracle : 오라클 기능만을 컨트롤하는 라이브러리
# - 판다스와 DB(oracle 포함 모든 Database) 기능을 연동해서 컨트롤해주는 라이브러리
#     - sqlalchemy 라이브러리 사용
#     - 데이터베이스의 쿼리 결과를 데이터 프레임으로 직접 받아 올 수 있음
#     - 데이터 프레임의 행/열 데이터를 DB에 테이블로 저장 시키는 기능이 있음

# %% [markdown]
# #### 사용할 라이브러리

# %%
import pandas as pd

### 판다스와 연동할 DB 라이브러리 정의
# - sqlalchemy 설치
# - pip install sqlalchemy
# - create_engine : DB 접속을 위한 라이브러리
# - types 는 기본 정의
from sqlalchemy import create_engine, types

# %%
### 오라클 서버로 접근하기
oracle = create_engine("oracle://busan:dbdb@localhost:1521/xe")
oracle
# Out:
# Engine(oracle://busan:***@localhost:1521/xe)

# %%
### 오라클 접속 정보 받아오기
conn = oracle.connect()
conn

# %%
### 구문 작성
sql = """
 SELECT *
 FROM member
 ORDER BY mem_name ASC
"""

### 판다스의 read_sql() 함수를 이용하여 데이터 조회
# - 데이터 프레임으로 반환
df_member = pd.read_sql(sql=sql, con=conn)
df_member.head(1)
# Out:
#   mem_id  mem_pass mem_name mem_regno1 mem_regno2    mem_bir  mem_zip  \
# 0   l001  12345678      구길동     881214    1234566 1988-12-14  339-841
#
#     mem_add1   mem_add2    mem_hometel     mem_comtel        mem_hp  \
# 0  충남금산군 금산읍   하리35-322  0412-322-8865  0412-322-8865  016-322-8865
#
#                  mem_mail mem_job mem_like mem_memorial mem_memorialday  \
# 0  email815@hanmail.co.kr     자영업       바둑        결혼기념일      1999-12-12
#
#    mem_mileage mem_delete
# 0         5300       None

# %% [markdown]
# #### 테이블 이름을 이용해서 데이터 프레임으로 정보 받아오기

# %%
### 특정 테이블에 있는 모든 정보를 데이터 프레임으로 조회
table_name = "member"
df_member2 = pd.read_sql_table(table_name=table_name, con=conn)
df_member2.head(1)
# Out:
#   mem_id  mem_pass mem_name mem_regno1 mem_regno2    mem_bir  mem_zip  \
# 0   a001  asdfasdf      김은대     760115    1406420 1976-01-15  135-972
#
#      mem_add1 mem_add2   mem_hometel    mem_comtel        mem_hp  \
# 0  대전시 동구 용운동  222-2번지  042-621-4615  042-621-4615  011-621-4615
#
#               mem_mail mem_job mem_like mem_memorial mem_memorialday  \
# 0  pyoedab@lycos.co.kr      주부       수영        결혼기념일      1999-01-12
#
#    mem_mileage mem_delete
# 0         1000       None

# %% [markdown]
# #### 데이터 프레임 데이터 -> DB 테이블 생성과 저장

# %%
### 데이터 프레임 데이터 -> DB에 테이블을 생성과 데이터 저장
# DB에 새로 생성할 Table 이름 정의
table_name = "member2"
df_member2.to_sql(name=table_name,
                                  con=conn,
                                  if_exists="replace",
                                  index=False
                                )

conn.commit()

# - if_exists에 사용할 수 있는 옵션
# - fail : name에 넣은 테이블 이름과 실제 테이블 이름이 존재하면 실패처리
# - append : 실제 테이블이 존재하면 데이터프레이므이 행을 실제 테이블에 추가하는 방식
# - replace : 실제 테이블이 존재하지 않으면 테이블 생성 후 데이터 추가 (주로 사용되는 옵션)
#                 : 실제 테이블이 존재하면 데이터프레임의 데이터로 대체

# %%
### 생성한 테이블에서 데이터 가져오기
pd.read_sql_table(table_name=table_name, con=conn)
# Out:
#    mem_id  mem_pass mem_name mem_regno1 mem_regno2    mem_bir  mem_zip  \
# 0    k001      7227      오철희     620123    1449311 1962-01-23  306-702
# 1    l001  12345678      구길동     881214    1234566 1988-12-14  339-841
# 2    m001      pass      박지은     750315    2555555 1975-03-15  306-702
# 3    n001      1111      탁원재     750323    1011014 1975-03-23  306-702
# 20      충남금산군 제원면          심내리123-1  0412-356-3578  0412-356-3578
# 21     충남 논산시 양촌면          산직3구 345   042-522-1679   042-522-1679
# 22    대전시 동구 가양1동            768-12   042-614-6914   042-614-6914
# 23     대전시 서구 삼천동     한신아파트305동309호   042-332-8976   042-332-8976
#
#           mem_hp                mem_mail mem_job mem_like mem_memorial  \
# 0   016-157-8765         equus@orgio.net     자영업       서예         아내생일
# 1   016-322-8865  email815@hanmail.co.kr     자영업       바둑        결혼기념일
# 2   016-252-0675       happy@hanmail.net     은행원       등산        아버님생신
# 3   019-632-2176     ping75@unitel.co.kr     축산업       낚시        결혼기념일
# 4   011-622-5971    tar-song@hanmail.net     회사원       등산        어머님생신
# 5   017-810-7658       sahra235@intz.com     공무원       독서         남편생일
# 6   017-823-2359         kph@hanmail.net     자영업       만화        결혼기념일
# 7   016-533-8768      econie@hanmail.net      학생       장기        어머님생신
# 8   019-222-8155      songej@hanmail.net     공무원       바둑        결혼기념일
# 9   011-272-8657        bob6@hanmail.net      학생     카레이싱        결혼기념일
# 10  018-273-9056        pss576@orgio.net      주부     영화감상        결혼기념일
# 11  017-240-8766       gagsong@orgio.net     자영업       낚시         남편생일
# 12  011-345-9877     songone@hanmail.net      학생       등산        결혼기념일
# 13  019-223-8767   happysong@hanmail.net      주부       독서        결혼기념일
# 14  011-621-4615     pyoedab@lycos.co.kr      주부       수영        결혼기념일
# 15  016-888-9999      engelcd@pretty.net     회사원       수영        아버님생신
# 16  011-123-5678      kyh01e@hanmail.net      교사       독서         아내생일
# 17  019-222-8877      dbs81f@hanmail.net     공무원       볼링        결혼기념일
# 18  011-432-8901     bosiang@hanmail.net      농업       당구        아버님생신
# 19  011-253-2121   SUPER-KHG@HANMAIL.NET      주부       볼링         아내생일
# 20  017-356-3578      lim052@hanmail.net      주부       스키        결혼기념일
# 21  019-522-1679      wingl7@hanmail.net     회사원       독서         아내생일
# 22  017-614-6914           pan@orgio.net     공무원       등산         남편생일
# 23  018-332-8976      maxsys@hanmail.net      농업       개그        결혼기념일
#
#    mem_memorialday  mem_mileage mem_delete
# 0       1999-11-12         3700       None
# 1       1999-12-12         5300       None
# 2       1999-12-12         1300       None
# 3       1999-02-12         2700       None
# 4       1999-03-12         2600       None
# 5       1999-05-12         2200       None
# 6       1999-06-12         1500       None
# 7       1999-07-12          700       None
# 8       1999-07-12         3200       None
# 9       1999-08-12         2200       None
# 10      1999-07-12         2700       None
# 11      1999-09-12         4300       None
# 12      1999-11-12         2700       None
# 13      1999-02-12         8700       None
# 14      1999-01-12         1000       None
# 15      1999-02-12         2300       None
# 16      1999-03-12         3500       None
# 17      1999-04-12         1700       None
# 18      1999-05-12         6500       None
# 19      1999-06-12         2700       None
# 20      1999-07-12          800       None
# 21      1999-08-12         1500       None
# 22      1999-09-12          900       None
# 23      1999-10-12         1100       None

# %%
conn.close()
